# %% [markdown]
# ---
#
# # Spotify songs analysis with lyrics
#
# Data comes from public github repository, however lyrics and language had been extracted by a Kaggle user.
# Data contains about 18000 records of songs with features like:
#
# - **Song Name**
# - **Lyrics**
# - **Release Date**
# - **Popularity**
# - **Genre**
# - **Language of Lyrics**
# - **Duration**
# - Other technical features f.ex. **Loudness**, **Danceability**, **Liveness**, ...
#
#
# One of the main purposes of this analysis is to see how different technical features vary across different **genres**, **languages** and other factors.<br><br>
# Next thing that would be nice is checking how the **dictionary of words changes with years** in songs across different genres, what are the **most common words** in genres across years, and maybe find some other interesting aspects.<br>
#
# I would also like to **create an estimator**, that will be able distinguish the **genre** of the song or specify which genre is the closest to your writing style.<br>
# <br>
#
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
sns.set_palette("inferno")

# %% [markdown]
# ---
#
# # Let's load the data
#
# ---

# %%
df_lyrics = pd.read_csv("data/spotify_songs_lyrics.csv")
df_lyrics.head(2)
# Out:
#                  track_id    track_name     track_artist  \
# 0  0017A6SJgTbfQVU2EtsPNo      Pangarap  Barbie's Cradle
# 1  004s3t0ONYlzxII9PLgU6z  I Feel Alive    Steady Rollin
#
#                                               lyrics  track_popularity  \
# 0  Minsan pa Nang ako'y napalingon Hindi ko alam ...                41
# 1  The trees, are singing in the wind The sky blu...                28
#
#            track_album_id track_album_name track_album_release_date  \
# 0  1srJQ0njEQgd8w4XSqI4JQ             Trip               2001-01-01
# 1  3z04Lb9Dsilqw68SHt6jLB      Love & Loss               2017-11-21
#
#         playlist_name             playlist_id  ... loudness mode  speechiness  \
# 0  Pinoy Classic Rock  37i9dQZF1DWYDQ8wBxd7xt  ...  -10.068    1       0.0236
# 1   Hard Rock Workout  3YouF0u7waJnolytf9JCXf  ...   -4.739    1       0.0442
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.2790           0.01170    0.0887    0.566   97.091       235440
# 1        0.0117           0.00994    0.3470    0.404  135.225       373512
#
#    language
# 0        tl
# 1        en
#
# [2 rows x 25 columns]

# %% [markdown]
# ---
#
# # Extracting year from release_date
#
# ---

# %%
df_lyrics["release_year"] = df_lyrics["track_album_release_date"].str[:4].astype(int)
df_lyrics["release_year"].head(2)
# Out:
# 0    2001
# 1    2017
# Name: release_year, dtype: int32

# %%
df = df_lyrics.drop(["track_id", "track_album_id", "playlist_id"], axis=1)
df["track_album_release_date"] = pd.to_dadf["track_album_release_date"].astype("datetime")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18454 entries, 0 to 18453
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_name         18454 non-null  object
#  1   track_artist       18454 non-null  object
#  2   lyrics             18194 non-null  object
#  3   track_popularity   18454 non-null  int64
#  4   track_album_name   18454 non-null  object
#  5   playlist_name      18454 non-null  object
#  6   playlist_genre     18454 non-null  object
#  7   playlist_subgenre  18454 non-null  object
#  8   danceability       18454 non-null  float64
#  9   energy             18454 non-null  float64
#  10  key                18454 non-null  int64
#  11  loudness           18454 non-null  float64
#  12  mode               18454 non-null  int64
#  13  speechiness        18454 non-null  float64
#  14  acousticness       18454 non-null  float64
#  15  instrumentalness   18454 non-null  float64
#  16  liveness           18454 non-null  float64
#  17  valence            18454 non-null  float64
#  18  tempo              18454 non-null  float64
#  19  duration_ms        18454 non-null  int64
#  20  language           18194 non-null  object
#  21  release_year       18454 non-null  int32
# dtypes: float64(9), int32(1), int64(4), object(8)
# memory usage: 3.0+ MB

# %%
df = df.dropna()

# %%
plt.figure(dpi=150)
sns.countplot(data=df, x="playlist_genre", hue="playlist_genre")
plt.title("Genres count", weight="bold")
plt.xlabel("Genre")
plt.ylabel("Amount")
plt.show()

# %%
p = sns.catplot(data=df,
                x="release_year",
                col="playlist_genre",
                kind="count",
                col_wrap=3,
                hue="playlist_genre",
               )
p.set_titles("{col_name}", weight="bold")
p.set_axis_labels("Amount", "Year of Release")
p.set(xticklabels=[]) 

plt.show()

# %%
plt.figure(figsize=(15,6), dpi=150)
sns.lineplot(data=df, x="release_year", y="duration_ms", hue="playlist_genre", errorbar=("ci", False))
plt.xticks(rotation=45)
plt.show()
